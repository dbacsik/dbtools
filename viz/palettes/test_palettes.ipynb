# %%
library(ggplot2)

# %%
options(repr.plot.width = 10, repr.plot.height = 5)

# %%
sample_plot <- ggplot(mpg, aes(x = displ, y = hwy, colour = drv)) +
  geom_point(size = 2.5) +
  labs(
    title = "Fuel Efficiency by Engine Displacement",
    subtitle = "Data from the US EPA, 1999-2008",
    x = "Engine Displacement (Litres)",
    y = "Highway Fuel Efficiency (MPG)",
    colour = "Vehicle Class",
    caption = "Source: ggplot2::mpg dataset"
  )

sample_plot
# Out:
# plot without title

# %%
source("../palettes/db_pals.R")
# Out:
# Loaded personal palettes from db_pals.R. Type `db_pals` to see a list of available options.

# %%
db_pals
# Out:
# $okabe_ito
# [1] "#E69F00" "#56B4E9" "#009E73" "#F5C710" "#0072B2" "#D55E00" "#CC79A7"
# [8] "#999999"
#
# $bacsik_bright
# [1] "#54d2d2" "#ff6150" "#ffcd00" "#33c080" "#9d50ac"
#
# $clinical_modern
# [1] "#F4D58D" "#8DB4D2" "#958ED2" "#D2958E" "#8ED2C2"

# %%
sample_plot + scale_color_manual(values = pal_okabe_ito)
# Out:
# plot without title

# %%
sample_plot + scale_color_manual(values = pal_bacsik_bright)
# Out:
# plot without title

# %%
sample_plot + scale_color_manual(values = pal_clinical_modern)
# Out:
# plot without title
