# %%
library(ggplot2)
source("https://raw.githubusercontent.com/dbacsik/dbtools/refs/heads/main/viz/ggplot/theme_clinical.R?token=GHSAT0AAAAAADPLNAMDBKAKVQZTMSC7OAX62KRRHIQ")
# Out:
# theme_clinical loaded. Default theme and color scales updated.

# %%
options(repr.plot.width = 10, repr.plot.height = 5)

# %%
sample_plot <- ggplot(mpg, aes(x = displ, y = hwy, colour = drv)) +
  geom_point(size = 2.5) +
  labs(
    title = "Fuel Efficiency by Engine Displacement",
    subtitle = "Data from the US EPA, 1999-2008",
    x = "Engine Displacement (Litres)",
    y = "Highway Fuel Efficiency (MPG)",
    colour = "Vehicle Class",
    caption = "Source: ggplot2::mpg dataset"
  )

sample_plot
# Out:
# plot without title

# %%
sample_plot <- ggplot(mpg, aes(x = displ, fill = drv)) +
  geom_histogram(binwidth=0.25, alpha=0.5) +
  labs(
    title = "Fuel Efficiency by Engine Displacement",
    subtitle = "Data from the US EPA, 1999-2008",
    x = "Engine Displacement (Litres)",
    y = "Highway Fuel Efficiency (MPG)",
    colour = "Vehicle Class",
    caption = "Source: ggplot2::mpg dataset"
  )

sample_plot
# Out:
# Ignoring unknown labels:
# * colour : "Vehicle Class"
# plot without title
