# %%
library(ggplot2)

# %%
options(repr.plot.width = 10, repr.plot.height = 5)

# %%
sample_dot <- ggplot(mpg, aes(x = displ, y = hwy, colour = drv)) +
  geom_point(size = 2.5) +
  labs(
    title = "Fuel Efficiency by Engine Displacement",
    subtitle = "Data from the US EPA, 1999-2008",
    x = "Engine Displacement (Litres)",
    y = "Highway Fuel Efficiency (MPG)",
    colour = "Vehicle Class",
    caption = "Source: ggplot2::mpg dataset"
  )

sample_dot
# Out:
# plot without title

# %%
sample_histo <- ggplot(mpg, aes(x = displ, fill = drv)) +
  geom_histogram(binwidth=0.25, alpha=0.8) +
  labs(
    title = "Fuel Efficiency by Engine Displacement",
    subtitle = "Data from the US EPA, 1999-2008",
    x = "Engine Displacement (Litres)",
    y = "Highway Fuel Efficiency (MPG)",
    fill = "Drive type",
    caption = "Source: ggplot2::mpg dataset"
  )

sample_histo
# Out:
# plot without title

# %%
#source("theme_clinical.R")
source("https://gitfront.io/r/dbacsik/Br9S897VuHE6/dbtools/raw/viz/ggplot/theme_clinical.R")
# Out:
# theme_clinical loaded. Default theme and color scales updated.

# %% [markdown]
# View with updated default theme:

# %%
sample_dot
# Out:
# plot without title

# %%
sample_histo
# Out:
# plot without title
